# %%
import pandas as pd

# %%
rate = pd.read_csv(r'C:\Users\tgrey\US Health Insurance\Rate2023.csv')

# %%
rate
# Out:
#          BusinessYear StateCode  IssuerId SourceName       ImportDate  \
# 0                2023        AK     21989       HIOS  11/19/2022 1:01
# 1                2023        AK     21989       HIOS  11/19/2022 1:01
# 2                2023        AK     21989       HIOS  11/19/2022 1:01
# 3                2023        AK     21989       HIOS  11/19/2022 1:01
# 4                2023        AK     21989       HIOS  11/19/2022 1:01
# ...               ...       ...       ...        ...              ...
# 1048570          2023        MS     14624       HIOS   1/28/2023 1:01
# 1048571          2023        MS     14624       HIOS   1/28/2023 1:01
# 1048572          2023        MS     14624       HIOS   1/28/2023 1:01
# 1048573          2023        MS     14624       HIOS   1/28/2023 1:01
# 1048574          2023        MS     14624       HIOS   1/28/2023 1:01
#
#         RateEffectiveDate RateExpirationDate          PlanId   RatingAreaId  \
# ...

# %%
rate.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName       ImportDate  \
# 0          2023        AK     21989       HIOS  11/19/2022 1:01
# 1          2023        AK     21989       HIOS  11/19/2022 1:01
# 2          2023        AK     21989       HIOS  11/19/2022 1:01
# 3          2023        AK     21989       HIOS  11/19/2022 1:01
# 4          2023        AK     21989       HIOS  11/19/2022 1:01
#
#   RateEffectiveDate RateExpirationDate          PlanId   RatingAreaId  \
# 0         10/1/2023         12/31/2023  21989AK0110001  Rating Area 1
# 1          1/1/2023         12/31/2023  21989AK0030001  Rating Area 1
# 2          1/1/2023          3/31/2023  21989AK0110001  Rating Area 1
# 3          4/1/2023          6/30/2023  21989AK0110001  Rating Area 1
# 4          7/1/2023          9/30/2023  21989AK0110001  Rating Area 1
#
#          Tobacco            Age  IndividualRate  IndividualTobaccoRate  \
# 0            NaN  Family Option           76.59                    NaN
# ...

# %%
rate.shape
# Out:
# (1048575, 20)

# %%
#to determine what states are listed -- duplicate numbers based on the issuerid/planid
rate1 = rate.groupby(['StateCode'])['StateCode'].count()

# %%
rate1
# Out:
# StateCode
# AK      3782
# AL     60257
# AZ     40560
# FL    574923
# GA    153510
# IN    121788
# LA     33099
# MO     58160
# MS      2496
# Name: StateCode, dtype: int64

# %%
trans = pd.read_excel(r'D:\Datasets\Transparency_in_Coverage_PUF.xlsx')

# %%
trans.head(3)
# Out:
#                                           Disclaimer
# 0  All issuer and plan level claims data is self-...
# 1  Enrollment disclaimer:  Data on enrollment ref...
# 2  Disenrollment disclaimer: Data on disenrollmen...

# %%
trans.shape
# Out:
# (8, 1)

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disclaimer  8 non-null      object
# dtypes: object(1)
# memory usage: 192.0+ bytes

# %%
trans.info
# Out:
# <bound method DataFrame.info of                                           Disclaimer
# 0  All issuer and plan level claims data is self-...
# 1  Enrollment disclaimer:  Data on enrollment ref...
# 2  Disenrollment disclaimer: Data on disenrollmen...
# 3  Claims denial data: Data on claims denials ref...
# 4  Claims appeals data: Data on claims appeals re...
# 5  Pharmacy claims received and denied data: Data...
# 6  Data organization in the PUF: Transparency in ...
# 7  Legend\n*                               Data n...>

# %%
hios = pd.read_excel(r'D:\Datasets\2021Q4-HIOS.xlsx')

# %%
hios.head()
# Out:
#    HIOS_ISSUER_ID                                      ISSR_LGL_NAME  \
# 0           10011        Southern Farm Bureau Life Insurance Company
# 1           10018                     Unified Life Insurance Company
# 2           10029  American National Life Insurance Company of Texas
# 3           10046             BEST Life and Health Insurance Company
# 4           10046             BEST Life and Health Insurance Company
#
#   MarketingName State IndividualMarket SmallGroupMarket UnknownMarket  \
# 0           NaN    TX              YES               NO            NO
# 1           NaN    SC              YES               NO            NO
# 2           NaN    MD              YES               NO            NO
# 3     BEST Life    HI              YES              YES            NO
# 4     BEST Life    HI              YES              YES            NO
#
#   LargeMarket  FEDERAL_EIN Active DateCreated LastModifiedDate  \
# ...

# %%
hios.shape
# Out:
# (7999, 19)

# %%
#to determine what states are listed -- duplicate numbers based on the issuerid/planid
hios1 = hios.groupby(['State'])['State'].count()

# %% [markdown]
# Includes US Territories

# %%
## AS American Samoa / GU Guam / PR Puerto Rico / MP?? ' VI Virgin Islands
hios1
# Out:
# State
# AK     89
# AL    139
# AR    136
# AS      4
# AZ    197
# CA    229
# CO    159
# CT    120
# DC    118
# DE    143
# FL    224
# GA    201
# GU     17
# HI     90
# IA    153
# ID    123
# IL    235
# IN    192
# KS    148
# KY    151
# LA    147
# MA    137
# MD    144
# ME     98
# MI    208
# MN    138
# MO    196
# MP      9
# MS    138
# MT     99
# NC    185
# ND    105
# NE    146
# NH    106
# NJ    150
# NM    133
# NV    156
# NY    184
# OH    236
# OK    154
# OR    164
# PA    222
# PR     39
# RI     83
# SC    154
# SD    107
# TN    166
# TX    294
# UT    149
# VA    208
# VI     23
# VT     73
# WA    154
# WI    196
# WV    120
# WY    110
# Name: State, dtype: int64

# %%
hios.dtypes
# Out:
# HIOS_ISSUER_ID                int64
# ISSR_LGL_NAME                object
# MarketingName                object
# State                        object
# IndividualMarket             object
# SmallGroupMarket             object
# UnknownMarket                object
# LargeMarket                  object
# FEDERAL_EIN                 float64
# Active                       object
# DateCreated          datetime64[ns]
# LastModifiedDate     datetime64[ns]
# DatabaseCompanyID           float64
# ORG_ADR1                     object
# ORG_ADR2                     object
# ORG_CITY                     object
# ORG_STATE                    object
# ORG_ZIP                     float64
# ORG_ZIP4                    float64
# dtype: object

# %%
hios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   HIOS_ISSUER_ID     7999 non-null   int64
#  1   ISSR_LGL_NAME      7999 non-null   object
#  2   MarketingName      3263 non-null   object
#  3   State              7999 non-null   object
#  4   IndividualMarket   7999 non-null   object
#  5   SmallGroupMarket   7999 non-null   object
#  6   UnknownMarket      7999 non-null   object
#  7   LargeMarket        7999 non-null   object
#  8   FEDERAL_EIN        7996 non-null   float64
#  9   Active             7999 non-null   object
#  10  DateCreated        7999 non-null   datetime64[ns]
#  11  LastModifiedDate   2783 non-null   datetime64[ns]
#  12  DatabaseCompanyID  7996 non-null   float64
#  13  ORG_ADR1           7874 non-null   object
#  14  ORG_ADR2           1825 non-null   object
# ...

# %%
# datatype conversion Federal_EIN / #12 / #17

# %%
#to determine what states are listed -- duplicate numbers based on the issuerid/planid
hios1 = hios.groupby(['State'])['State'].count()

# %%
#assess the number of issuer organizations
hios2 = hios.groupby(['ISSR_LGL_NAME'])['ISSR_LGL_NAME'].count()

# %%
hios2
# Out:
# ISSR_LGL_NAME
# 3B Group, Inc.                            1
# 4 Ever Life Insurance Company            27
# AAA Access Dental Plan of Texas, Inc.     1
# ABC Auto Parts Ltd                        1
# ACE American Insurance Company           15
#                                          ..
# eternalHealth, Inc.                       1
# exp US Services Inc                       1
# iHeart Media, Inc.                        1
# lutheran medical center                   1
# nHealth, Inc.                             1
# Name: ISSR_LGL_NAME, Length: 1575, dtype: int64

# %%
hios2.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1575 entries, 3B Group, Inc. to nHealth, Inc.
# Series name: ISSR_LGL_NAME
# Non-Null Count  Dtype
# --------------  -----
# 1575 non-null   int64
# dtypes: int64(1)
# memory usage: 56.9+ KB

# %%
hios.display.max_columns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 hios.display.max_columns()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'display'
