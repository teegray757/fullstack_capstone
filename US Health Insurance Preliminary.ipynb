# %%
import pandas as pd
import sqlite3

# %%
cw2015 = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\Crosswalk2015.csv')
# Out:
# C:\Users\tgrey\AppData\Local\Temp\ipykernel_14184\1132842553.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   cw2015 = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\Crosswalk2015.csv')

# %% [markdown]
# ##CrossWalk2015

# %%
cw2015
# Out:
#          index State DentalPlan     PlanID_2014  IssuerID_2014  \
# 0            0    AK          Y  21989AK0010001          21989
# 1            1    AK          Y  21989AK0010001          21989
# 2            2    AK          Y  21989AK0010001          21989
# 3            3    AK          Y  21989AK0010001          21989
# 4            4    AK          Y  21989AK0010001          21989
# ...        ...   ...        ...             ...            ...
# 132500  132500    WY          Y  83964WY0010004          83964
# 132501  132501    WY          Y  83964WY0010004          83964
# 132502  132502    WY          Y  83964WY0010004          83964
# 132503  132503    WY          Y  83964WY0010004          83964
# 132504  132504    WY          Y  83964WY0010004          83964
#
#        MultistatePlan_2014 MetalLevel_2014  ChildAdultOnly_2014  FIPSCode  \
# 0                        N             Low                    0      2013
# ...

# %%
cw2015.shape
# Out:
# (132505, 22)

# %%
cw2015.dtypes
# Out:
# index                         int64
# State                        object
# DentalPlan                   object
# PlanID_2014                  object
# IssuerID_2014                 int64
# MultistatePlan_2014          object
# MetalLevel_2014              object
# ChildAdultOnly_2014           int64
# FIPSCode                      int64
# ZipCode                       int64
# CrosswalkLevel                int64
# ReasonForCrosswalk            int64
# PlanID_2015                  object
# IssuerID_2015                 int64
# MultistatePlan_2015          object
# MetalLevel_2015              object
# ChildAdultOnly_2015          object
# AgeOffPlanID_2015            object
# IssuerID_AgeOff2015           int64
# MultistatePlan_AgeOff2015    object
# MetalLevel_AgeOff2015        object
# ChildAdultOnly_AgeOff2015    object
# dtype: object

# %%
cw2015.nunique()
# Out:
# index                        132505
# State                            35
# DentalPlan                        2
# PlanID_2014                    3514
# IssuerID_2014                   300
# MultistatePlan_2014               2
# MetalLevel_2014                   7
# ChildAdultOnly_2014               3
# FIPSCode                       2545
# ZipCode                         449
# CrosswalkLevel                    5
# ReasonForCrosswalk                7
# PlanID_2015                    2930
# IssuerID_2015                   279
# MultistatePlan_2015               3
# MetalLevel_2015                   8
# ChildAdultOnly_2015               6
# AgeOffPlanID_2015               359
# IssuerID_AgeOff2015             182
# MultistatePlan_AgeOff2015         1
# MetalLevel_AgeOff2015             6
# ChildAdultOnly_AgeOff2015         3
# dtype: int64

# %%
cw2015.count()
# Out:
# index                        132505
# State                        132505
# DentalPlan                   132505
# PlanID_2014                  132505
# IssuerID_2014                132505
# MultistatePlan_2014          132505
# MetalLevel_2014              132505
# ChildAdultOnly_2014          132505
# FIPSCode                     132505
# ZipCode                      132505
# CrosswalkLevel               132505
# ReasonForCrosswalk           132505
# PlanID_2015                  132505
# IssuerID_2015                132505
# MultistatePlan_2015          132505
# MetalLevel_2015              132505
# ChildAdultOnly_2015          132505
# AgeOffPlanID_2015            132505
# IssuerID_AgeOff2015          132505
# MultistatePlan_AgeOff2015    114632
# MetalLevel_AgeOff2015        132449
# ChildAdultOnly_AgeOff2015    132449
# dtype: int64

# %%
cw2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132505 entries, 0 to 132504
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      132505 non-null  int64
#  1   State                      132505 non-null  object
#  2   DentalPlan                 132505 non-null  object
#  3   PlanID_2014                132505 non-null  object
#  4   IssuerID_2014              132505 non-null  int64
#  5   MultistatePlan_2014        132505 non-null  object
#  6   MetalLevel_2014            132505 non-null  object
#  7   ChildAdultOnly_2014        132505 non-null  int64
#  8   FIPSCode                   132505 non-null  int64
#  9   ZipCode                    132505 non-null  int64
#  10  CrosswalkLevel             132505 non-null  int64
#  11  ReasonForCrosswalk         132505 non-null  int64
#  12  PlanID_2015                132505 non-null  object
# ...

# %%
cw2015.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         index  State  DentalPlan  PlanID_2014  IssuerID_2014  \
# 0       False  False       False        False          False
# 1       False  False       False        False          False
# 2       False  False       False        False          False
# 3       False  False       False        False          False
# 4       False  False       False        False          False
# ...       ...    ...         ...          ...            ...
# 132500  False  False       False        False          False
# 132501  False  False       False        False          False
# 132502  False  False       False        False          False
# 132503  False  False       False        False          False
# 132504  False  False       False        False          False
#
#         MultistatePlan_2014  MetalLevel_2014  ChildAdultOnly_2014  FIPSCode  \
# 0                     False            False                False     False
# ...

# %%
ntwork = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\Network.csv')

# %%
ntwork.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3822 entries, 0 to 3821
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           3822 non-null   int64
#  1   BusinessYear    3822 non-null   int64
#  2   StateCode       3822 non-null   object
#  3   IssuerId        3822 non-null   int64
#  4   SourceName      3822 non-null   object
#  5   VersionNum      3822 non-null   int64
#  6   ImportDate      3822 non-null   object
#  7   IssuerId2       3822 non-null   int64
#  8   StateCode2      3822 non-null   object
#  9   NetworkName     3822 non-null   object
#  10  NetworkId       3822 non-null   object
#  11  NetworkURL      3822 non-null   object
#  12  RowNumber       3822 non-null   int64
#  13  MarketCoverage  1867 non-null   object
#  14  DentalOnlyPlan  1867 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 448.0+ KB

# %%
ntwork.shape
# Out:
# (3822, 15)

# %%
ntwork.head(20)
# Out:
#     index  BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0       0          2014        AK     21989       HIOS           6
# 1       1          2014        AK     38344       HIOS           6
# 2       2          2014        AK     38536       HIOS           2
# 3       3          2014        AK     42507       HIOS           3
# 4       4          2014        AK     73836       HIOS           6
# 5       5          2014        AK     73836       HIOS           6
# 6       6          2014        AK     74819       HIOS           7
# 7       7          2014        AK     84859       HIOS           1
# 8       8          2014        AL     12538       HIOS           8
# 9       9          2014        AL     12538       HIOS           8
# 10     10          2014        AL     17540       HIOS           3
# 11     11          2014        AL     44580       HIOS          10
# 12     12          2014        AL     44580       HIOS          10
# ...

# %%
ntwork.isnull().sum()
# Out:
# index                0
# BusinessYear         0
# StateCode            0
# IssuerId             0
# SourceName           0
# VersionNum           0
# ImportDate           0
# IssuerId2            0
# StateCode2           0
# NetworkName          0
# NetworkId            0
# NetworkURL           0
# RowNumber            0
# MarketCoverage    1955
# DentalOnlyPlan    1955
# dtype: int64

# %%
ntwork.head()
# Out:
#    index  BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0      0          2014        AK     21989       HIOS           6
# 1      1          2014        AK     38344       HIOS           6
# 2      2          2014        AK     38536       HIOS           2
# 3      3          2014        AK     42507       HIOS           3
# 4      4          2014        AK     73836       HIOS           6
#
#             ImportDate  IssuerId2 StateCode2             NetworkName  \
# 0  2014-03-19 07:06:49      21989         AK             ODS Premier
# 1  2013-08-28 08:15:53      38344         AK            HeritagePlus
# 2  2013-08-01 12:48:00      38536         AK  Lincoln Dental Connect
# 3  2013-09-02 11:39:25      42507         AK   DentalGuard Preferred
# 4  2014-04-18 11:49:29      73836         AK   Moda Plus AK Regional
#
#   NetworkId                                         NetworkURL  RowNumber  \
# 0    AKN001  https://www.modahealth.com/ProviderSearch/face...         13
# ...

# %%
#checking the info in this column 1955 NULL values listed (object) 
#This column identifies the type of coverage: "Individual or SHOP"
ntwork['MarketCoverage'].tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
ntwork['DentalOnlyPlan'].tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
print(ntwork.isnull().sum())
# Out:
# index                0
# BusinessYear         0
# StateCode            0
# IssuerId             0
# SourceName           0
# VersionNum           0
# ImportDate           0
# IssuerId2            0
# StateCode2           0
# NetworkName          0
# NetworkId            0
# NetworkURL           0
# RowNumber            0
# MarketCoverage    1955
# DentalOnlyPlan    1955
# dtype: int64

# %%
print(ntwork.count())
# Out:
# index             3822
# BusinessYear      3822
# StateCode         3822
# IssuerId          3822
# SourceName        3822
# VersionNum        3822
# ImportDate        3822
# IssuerId2         3822
# StateCode2        3822
# NetworkName       3822
# NetworkId         3822
# NetworkURL        3822
# RowNumber         3822
# MarketCoverage    1867
# DentalOnlyPlan    1867
# dtype: int64

# %%
plans = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\PlanAttributes.csv')
# Out:
# C:\Users\tgrey\AppData\Local\Temp\ipykernel_14184\3893249114.py:1: DtypeWarning: Columns (1,8,9,10,11,12,13,14,15,16,19,20,21,23,24,25,26,27,28,29,30,32,33,34,35,40,41,42,43,67,68,69,71,72,73,76,77,78,80,81,82,83,85,86,87,89,90,91,93,94,95,97,98,99,137,138,139,141,142,143,146,147,148,151,152,153,155,156,157,159,160,161,163,164,165,167,168,169) have mixed types. Specify dtype option on import or set low_memory=False.
#   plans = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\PlanAttributes.csv')

# %%
plans.head()
# Out:
#    index AVCalculatorOutputNumber  \
# 0      0                      NaN
# 1      1                      NaN
# 2      2                      NaN
# 3      3                      NaN
# 4      4                      NaN
#
#    BeginPrimaryCareCostSharingAfterNumberOfVisits  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays  BenefitPackageId  \
# 0                                                  0                        1
# 1                                                  0                        1
# 2                                                  0                        1
# 3                                                  0                        1
# ...

# %%
plans.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77353 entries, 0 to 77352
# Data columns (total 177 columns):
#  #    Column                                                        Non-Null Count  Dtype
# ---   ------                                                        --------------  -----
#  0    index                                                         77353 non-null  int64
#  1    AVCalculatorOutputNumber                                      54528 non-null  object
#  2    BeginPrimaryCareCostSharingAfterNumberOfVisits                77353 non-null  int64
#  3    BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays      77353 non-null  int64
#  4    BenefitPackageId                                              77353 non-null  int64
#  5    BusinessYear                                                  77353 non-null  int64
#  6    CSRVariationType                                              77353 non-null  object
# ...

# %%
plans.shape
# Out:
# (77353, 177)

# %%
plans.dtypes
# Out:
# index                                                        int64
# AVCalculatorOutputNumber                                    object
# BeginPrimaryCareCostSharingAfterNumberOfVisits               int64
# BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays     int64
# BenefitPackageId                                             int64
#                                                              ...
# URLForEnrollmentPayment                                     object
# URLForSummaryofBenefitsCoverage                             object
# UniquePlanDesign                                            object
# VersionNum                                                   int64
# WellnessProgramOffered                                      object
# Length: 177, dtype: object

# %%
plans.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        index  AVCalculatorOutputNumber  \
# 0      False                      True
# 1      False                      True
# 2      False                      True
# 3      False                      True
# 4      False                      True
# ...      ...                       ...
# 77348  False                      True
# 77349  False                      True
# 77350  False                      True
# 77351  False                      True
# 77352  False                      True
#
#        BeginPrimaryCareCostSharingAfterNumberOfVisits  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# ...

# %%
plans.dtypes
# Out:
# index                                                        int64
# AVCalculatorOutputNumber                                    object
# BeginPrimaryCareCostSharingAfterNumberOfVisits               int64
# BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays     int64
# BenefitPackageId                                             int64
#                                                              ...
# URLForEnrollmentPayment                                     object
# URLForSummaryofBenefitsCoverage                             object
# UniquePlanDesign                                            object
# VersionNum                                                   int64
# WellnessProgramOffered                                      object
# Length: 177, dtype: object

# %%
plans.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 77348    False
# 77349    False
# 77350    False
# 77351    False
# 77352    False
# Length: 77353, dtype: bool

# %%
rate = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\Rate.csv')

# %%
rate
# Out:
#            index  BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              0          2014        AK     21989       HIOS           6
# 1              1          2014        AK     21989       HIOS           6
# 2              2          2014        AK     21989       HIOS           6
# 3              3          2014        AK     21989       HIOS           6
# 4              4          2014        AK     21989       HIOS           6
# ...          ...           ...       ...       ...        ...         ...
# 1048570  1048570          2014        IN     50816       HIOS           9
# 1048571  1048571          2014        IN     50816       HIOS           9
# 1048572  1048572          2014        IN     50816       HIOS           9
# 1048573  1048573          2014        IN     50816       HIOS           9
# 1048574  1048574          2014        IN     50816       HIOS           9
#
#              ImportDate  FederalTIN RateEffectiveDate RateExpirationDate  \
# ...

# %% [raw]
# rate.info()

# %%
rate.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Length: 1048575, dtype: bool

# %%
rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   index                  1048575 non-null  int64
#  1   BusinessYear           1048575 non-null  int64
#  2   StateCode              1048575 non-null  object
#  3   IssuerId               1048575 non-null  int64
#  4   SourceName             1048575 non-null  object
#  5   VersionNum             1048575 non-null  int64
#  6   ImportDate             1048575 non-null  object
#  7   FederalTIN             1048575 non-null  object
#  8   RateEffectiveDate      1048575 non-null  object
#  9   RateExpirationDate     1048575 non-null  object
#  10  PlanId                 1048575 non-null  object
#  11  RatingAreaId           1048575 non-null  object
#  12  Tobacco                1048575 non-null  object
#  13  Age                    1048575 non-null  object
# ...

# %%
rate.head()
# Out:
#    index  BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0      0          2014        AK     21989       HIOS           6
# 1      1          2014        AK     21989       HIOS           6
# 2      2          2014        AK     21989       HIOS           6
# 3      3          2014        AK     21989       HIOS           6
# 4      4          2014        AK     21989       HIOS           6
#
#      ImportDate  FederalTIN RateEffectiveDate RateExpirationDate  \
# 0  3/19/14 7:06  93-0438772            1/1/14           12/31/14
# 1  3/19/14 7:06  93-0438772            1/1/14           12/31/14
# 2  3/19/14 7:06  93-0438772            1/1/14           12/31/14
# 3  3/19/14 7:06  93-0438772            1/1/14           12/31/14
# 4  3/19/14 7:06  93-0438772            1/1/14           12/31/14
#
#            PlanId   RatingAreaId        Tobacco            Age  \
# 0  21989AK0010001  Rating Area 1  No Preference           0-20
# ...

# %%
rate.shape
# Out:
# (1048575, 16)

# %%
area = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\ServiceArea.csv')

# %%
area
# Out:
#        index  BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          0          2014        PA     22444       HIOS           9
# 1          1          2014        PA     22444       HIOS           9
# 2          2          2014        PA     22444       HIOS           9
# 3          3          2014        PA     22444       HIOS           9
# 4          4          2014        PA     22444       HIOS           9
# ...      ...           ...       ...       ...        ...         ...
# 42242  42242          2016        WV     96480      SERFF           2
# 42243  42243          2016        WV     96480      SERFF           2
# 42244  42244          2016        WV     96480      SERFF           2
# 42245  42245          2016        WV     96480      SERFF           2
# 42246  42246          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2 StateCode2 ServiceAreaId  \
# ...

# %%
area.columns
# Out:
# Index(['index', 'BusinessYear', 'StateCode', 'IssuerId', 'SourceName',
#        'VersionNum', 'ImportDate', 'IssuerId2', 'StateCode2', 'ServiceAreaId',
#        'ServiceAreaName', 'CoverEntireState', 'County', 'PartialCounty',
#        'ZipCodes', 'PartialCountyJustification', 'RowNumber', 'MarketCoverage',
#        'DentalOnlyPlan'],
#       dtype='object')

# %%
area.shape
# Out:
# (42247, 19)

# %%
area.tail(20)
# Out:
#        index  BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 42227  42227          2016        WV     94562      SERFF           2
# 42228  42228          2016        WV     96480      SERFF           2
# 42229  42229          2016        WV     96480      SERFF           2
# 42230  42230          2016        WV     96480      SERFF           2
# 42231  42231          2016        WV     96480      SERFF           2
# 42232  42232          2016        WV     96480      SERFF           2
# 42233  42233          2016        WV     96480      SERFF           2
# 42234  42234          2016        WV     96480      SERFF           2
# 42235  42235          2016        WV     96480      SERFF           2
# 42236  42236          2016        WV     96480      SERFF           2
# 42237  42237          2016        WV     96480      SERFF           2
# 42238  42238          2016        WV     96480      SERFF           2
# ...

# %%
area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42247 entries, 0 to 42246
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   index                       42247 non-null  int64
#  1   BusinessYear                42247 non-null  int64
#  2   StateCode                   42247 non-null  object
#  3   IssuerId                    42247 non-null  int64
#  4   SourceName                  42247 non-null  object
#  5   VersionNum                  42247 non-null  int64
#  6   ImportDate                  42247 non-null  object
#  7   IssuerId2                   42247 non-null  int64
#  8   StateCode2                  42247 non-null  object
#  9   ServiceAreaId               42247 non-null  object
#  10  ServiceAreaName             42247 non-null  object
#  11  CoverEntireState            42247 non-null  object
#  12  County                      40452 non-null  float64
# ...

# %%
plans.columns
# Out:
# Index(['index', 'AVCalculatorOutputNumber',
#        'BeginPrimaryCareCostSharingAfterNumberOfVisits',
#        'BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays',
#        'BenefitPackageId', 'BusinessYear', 'CSRVariationType',
#        'ChildOnlyOffering', 'ChildOnlyPlanId', 'CompositeRatingOffered',
#        ...
#        'TEHBOutOfNetFamilyMOOP', 'TEHBOutOfNetFamilyPerGroupMOOP',
#        'TEHBOutOfNetFamilyPerPersonMOOP', 'TEHBOutOfNetIndividualMOOP', 'TIN',
#        'URLForEnrollmentPayment', 'URLForSummaryofBenefitsCoverage',
#        'UniquePlanDesign', 'VersionNum', 'WellnessProgramOffered'],
#       dtype='object', length=177)

# %%
plans.shape
# Out:
# (77353, 177)

# %%
plans.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 77348    False
# 77349    False
# 77350    False
# 77351    False
# 77352    False
# Length: 77353, dtype: bool

# %%
area.isnull().sum()
# Out:
# index                             0
# BusinessYear                      0
# StateCode                         0
# IssuerId                          0
# SourceName                        0
# VersionNum                        0
# ImportDate                        0
# IssuerId2                         0
# StateCode2                        0
# ServiceAreaId                     0
# ServiceAreaName                   0
# CoverEntireState                  0
# County                         1795
# PartialCounty                  1795
# ZipCodes                      41631
# PartialCountyJustification    41631
# RowNumber                         0
# MarketCoverage                19925
# DentalOnlyPlan                19925
# dtype: int64

# %%
rules = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\BusinessRules.csv')

# %%
rules
# Out:
#        index  BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          0          2014        AL     82285       HIOS           7
# 1          1          2014        AL     82285       HIOS           7
# 2          2          2014        AL     82285       HIOS           7
# 3          3          2014        AL     82285       HIOS           7
# 4          4          2014        AL     82285       HIOS           7
# ...      ...           ...       ...       ...        ...         ...
# 21080  21080          2016        WV     94562      SERFF           2
# 21081  21081          2016        WV     96480      SERFF           2
# 21082  21082          2016        WV     96480      SERFF           2
# 21083  21083          2016        WV     96480      SERFF           2
# 21084  21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN   ProductId  ...  \
# ...

# %%
rules.shape
# Out:
# (21085, 24)

# %%
rules.dtypes
# Out:
# index                                     int64
# BusinessYear                              int64
# StateCode                                object
# IssuerId                                  int64
# SourceName                               object
# VersionNum                                int64
# ImportDate                               object
# IssuerId2                                 int64
# TIN                                      object
# ProductId                                object
# StandardComponentId                      object
# EnrolleeContractRateDeterminationRule    object
# TwoParentFamilyMaxDependentsRule         object
# SingleParentFamilyMaxDependentsRule      object
# DependentMaximumAgRule                   object
# ChildrenOnlyContractMaxChildrenRule      object
# DomesticPartnerAsSpouseIndicator         object
# SameSexPartnerAsSpouseIndicator          object
# AgeDeterminationRule                     object
# MinimumTobaccoFreeMonthsRule             object
# ...

# %%
rules.nunique()
# Out:
# index                                    21085
# BusinessYear                                 3
# StateCode                                   39
# IssuerId                                   910
# SourceName                                   3
# VersionNum                                  23
# ImportDate                                 268
# IssuerId2                                  910
# TIN                                        343
# ProductId                                 3034
# StandardComponentId                      14189
# EnrolleeContractRateDeterminationRule        2
# TwoParentFamilyMaxDependentsRule             3
# SingleParentFamilyMaxDependentsRule          3
# DependentMaximumAgRule                      12
# ChildrenOnlyContractMaxChildrenRule          2
# DomesticPartnerAsSpouseIndicator             2
# SameSexPartnerAsSpouseIndicator              2
# AgeDeterminationRule                         3
# MinimumTobaccoFreeMonthsRule                 7
# ...

# %%
rules.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21080    False
# 21081    False
# 21082    False
# 21083    False
# 21084    False
# Length: 21085, dtype: bool

# %%
list(plans.columns)
# Out:
# ['index',
#  'AVCalculatorOutputNumber',
#  'BeginPrimaryCareCostSharingAfterNumberOfVisits',
#  'BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays',
#  'BenefitPackageId',
#  'BusinessYear',
#  'CSRVariationType',
#  'ChildOnlyOffering',
#  'ChildOnlyPlanId',
#  'CompositeRatingOffered',
#  'DEHBCombInnOonFamilyMOOP',
#  'DEHBCombInnOonFamilyPerGroupMOOP',
#  'DEHBCombInnOonFamilyPerPersonMOOP',
#  'DEHBCombInnOonIndividualMOOP',
#  'DEHBDedCombInnOonFamily',
#  'DEHBDedCombInnOonFamilyPerGroup',
#  'DEHBDedCombInnOonFamilyPerPerson',
#  'DEHBDedCombInnOonIndividual',
#  'DEHBDedInnTier1Coinsurance',
#  'DEHBDedInnTier1Family',
#  'DEHBDedInnTier1FamilyPerGroup',
#  'DEHBDedInnTier1FamilyPerPerson',
#  'DEHBDedInnTier1Individual',
#  'DEHBDedInnTier2Coinsurance',
#  'DEHBDedInnTier2Family',
#  'DEHBDedInnTier2FamilyPerGroup',
#  'DEHBDedInnTier2FamilyPerPerson',
#  'DEHBDedInnTier2Individual',
#  'DEHBDedOutOfNetFamily',
#  'DEHBDedOutOfNetFamilyPerGroup',
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
plans.head()
# Out:
#    index AVCalculatorOutputNumber  \
# 0      0                      NaN
# 1      1                      NaN
# 2      2                      NaN
# 3      3                      NaN
# 4      4                      NaN
#
#    BeginPrimaryCareCostSharingAfterNumberOfVisits  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays  BenefitPackageId  \
# 0                                                  0                        1
# 1                                                  0                        1
# 2                                                  0                        1
# 3                                                  0                        1
# ...

# %%
cw_2016 = pd.read_csv(r'C:\Users\tgrey\Capstone_US_Health\US Health Ins\Crosswalk2016.csv')

# %%
cw_2016
# Out:
#          index State DentalPlan     PlanID_2015  IssuerID_2015  \
# 0            0    OR          N  10091OR0360004          10091
# 1            1    OR          N  10091OR0360004          10091
# 2            2    OR          N  10091OR0360004          10091
# 3            3    OR          N  10091OR0360004          10091
# 4            4    OR          N  10091OR0360004          10091
# ...        ...   ...        ...             ...            ...
# 150000  150000    OH          Y  99969OH0060005          99969
# 150001  150001    OH          Y  99969OH0060005          99969
# 150002  150002    OH          Y  99969OH0060005          99969
# 150003  150003    OH          Y  99969OH0060005          99969
# 150004  150004    OH          Y  99969OH0060005          99969
#
#        MultistatePlan_2015 MetalLevel_2015  ChildAdultOnly_2015  FIPSCode  \
# 0                        N          Bronze                    0     41021
# ...

# %%
cw_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150005 entries, 0 to 150004
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      150005 non-null  int64
#  1   State                      150005 non-null  object
#  2   DentalPlan                 150005 non-null  object
#  3   PlanID_2015                150005 non-null  object
#  4   IssuerID_2015              150005 non-null  int64
#  5   MultistatePlan_2015        150005 non-null  object
#  6   MetalLevel_2015            150005 non-null  object
#  7   ChildAdultOnly_2015        150005 non-null  int64
#  8   FIPSCode                   150005 non-null  int64
#  9   ZipCode                    150005 non-null  int64
#  10  CrosswalkLevel             150005 non-null  int64
#  11  ReasonForCrosswalk         150005 non-null  int64
#  12  PlanID_2016                150005 non-null  object
# ...

# %%
cw_combo = pd.read_csv(r'C:\Users\tgrey\US Health Insurance\cw_combo.csv')
# Out:
# C:\Users\tgrey\AppData\Local\Temp\ipykernel_14184\2490864608.py:1: DtypeWarning: Columns (6,9,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   cw_combo = pd.read_csv(r'C:\Users\tgrey\US Health Insurance\cw_combo.csv')

# %%
cw_combo
# Out:
#         Plan_YR State DentalPlan          PlanID Multistateplan Metal_Level  \
# 0          2014    AK          Y  21989AK0010001              N         Low
# 1          2014    AK          Y  21989AK0010001              N         Low
# 2          2014    AK          Y  21989AK0010001              N         Low
# 3          2014    AK          Y  21989AK0010001              N         Low
# 4          2014    AK          Y  21989AK0010001              N         Low
# ...         ...   ...        ...             ...            ...         ...
# 415010     2016    OH          Y  99969OH0060005              N        High
# 415011     2016    OH          Y  99969OH0060005              N        High
# 415012     2016    OH          Y  99969OH0060005              N        High
# 415013     2016    OH          Y  99969OH0060005              N        High
# 415014     2016    OH          Y  99969OH0060005              N        High
#
# ...

# %%
cw_combo.head(20)
# Out:
#     Plan_YR State DentalPlan          PlanID Multistateplan Metal_Level  \
# 0      2014    AK          Y  21989AK0010001              N         Low
# 1      2014    AK          Y  21989AK0010001              N         Low
# 2      2014    AK          Y  21989AK0010001              N         Low
# 3      2014    AK          Y  21989AK0010001              N         Low
# 4      2014    AK          Y  21989AK0010001              N         Low
# 5      2014    AK          Y  21989AK0010001              N         Low
# 6      2014    AK          Y  21989AK0010001              N         Low
# 7      2014    AK          Y  21989AK0010001              N         Low
# 8      2014    AK          Y  21989AK0010001              N         Low
# 9      2014    AK          Y  21989AK0010001              N         Low
# 10     2014    AK          Y  21989AK0010001              N         Low
# 11     2014    AK          Y  21989AK0010001              N         Low
# ...

# %%
cw_combo.shape
# Out:
# (415015, 14)

# %%
cw_combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415015 entries, 0 to 415014
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Plan_YR                415015 non-null  int64
#  1   State                  415015 non-null  object
#  2   DentalPlan             415015 non-null  object
#  3   PlanID                 415015 non-null  object
#  4   Multistateplan         415015 non-null  object
#  5   Metal_Level            415015 non-null  object
#  6   ChildAdultOnly         415015 non-null  object
#  7   FIPSCode               415015 non-null  int64
#  8   ZipCode                415015 non-null  int64
#  9   AgeOffPlanID           282510 non-null  object
#  10  IssuerID_AgeOff        282510 non-null  float64
#  11  MultistatePlan_AgeOff  264637 non-null  object
#  12  MetalLevel_AgeOff      282454 non-null  object
#  13  ChildAdultOnly_AgeOff  282454 non-null  object
# ...

# %%
benefits= pd.read_csv(r'C:\Users\tgrey\US Health Insurance\BenefitsCostSharing.csv')
# Out:
# C:\Users\tgrey\AppData\Local\Temp\ipykernel_14184\4195779912.py:1: DtypeWarning: Columns (3,6,9,10,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   benefits= pd.read_csv(r'C:\Users\tgrey\US Health Insurance\BenefitsCostSharing.csv')

# %%
benefits.head(5)
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014           20%           NaN
# 1     Dental Check-Up for Children          2014           20%           NaN
# 2        Basic Dental Care - Child          2014           40%           NaN
# 3              Orthodontia - Child          2014           50%           NaN
# 4        Major Dental Care - Child          2014           50%           NaN
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
# 2           40%     No Charge           NaN     No Charge
# 3           50%     No Charge           NaN     No Charge
# 4           50%     No Charge           NaN     No Charge
#
#              EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# ...

# %%
benefits.shape
# Out:
# (5048408, 32)

# %%
pd.set_option('display.max_columns', 500)

# %%
benefits.head()
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014           20%           NaN
# 1     Dental Check-Up for Children          2014           20%           NaN
# 2        Basic Dental Care - Child          2014           40%           NaN
# 3              Orthodontia - Child          2014           50%           NaN
# 4        Major Dental Care - Child          2014           50%           NaN
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
# 2           40%     No Charge           NaN     No Charge
# 3           50%     No Charge           NaN     No Charge
# 4           50%     No Charge           NaN     No Charge
#
#              EHBVarReason Exclusions  \
# 0               Above EHB        NaN
# 1     Substantially Equal        NaN
# ...
